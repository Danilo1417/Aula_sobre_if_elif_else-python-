# %% [markdown]
# <a href="https://colab.research.google.com/github/Danilo1417/Aula_sobre_if_elif_else-python-/blob/main/Atividade_de_if_elif_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#atividade 01
numero = float(input("Digite um número:"))
if numero > 0:
  print("Número positivo")
elif numero == 0:
  print("Número nulo")
else:
  print("Número negativo")
